# %% [markdown]
# #### Installing the library

# %%
# !pip install cowin
# Out:
# ...
#      |████████████████████████████████| 286kB 20.2MB/s
# ...
#      |████████████████████████████████| 61kB 8.0MB/s
# ...
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-cp37-none-any.whl size=13485 sha256=d5676e5e93d03f855a7f5c8151ee78aae841a467b030c4254227e3e6d5d580a5
#   Stored in directory: /root/.cache/pip/wheels/5e/63/09/d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# Successfully built fake-useragent
# ERROR: google-colab 1.0.0 has requirement requests~=2.23.0, but you'll have requests 2.25.1 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
# ...

# %% [markdown]
# #### Initializing cowin

# %%
from cowin_api import CoWinAPI

cowin = CoWinAPI()
dir(cowin)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_call_api',
#  'get_availability_by_base',
#  'get_availability_by_district',
#  'get_availability_by_pincode',
#  'get_districts',
#  'get_states']

# %% [markdown]
# #### Getting all states

# %%
states = cowin.get_states()
print(states)
# Out:
# {'states': [{'state_id': 1, 'state_name': 'Andaman and Nicobar Islands'}, {'state_id': 2, 'state_name': 'Andhra Pradesh'}, {'state_id': 3, 'state_name': 'Arunachal Pradesh'}, {'state_id': 4, 'state_name': 'Assam'}, {'state_id': 5, 'state_name': 'Bihar'}, {'state_id': 6, 'state_name': 'Chandigarh'}, {'state_id': 7, 'state_name': 'Chhattisgarh'}, {'state_id': 8, 'state_name': 'Dadra and Nagar Haveli'}, {'state_id': 37, 'state_name': 'Daman and Diu'}, {'state_id': 9, 'state_name': 'Delhi'}, {'state_id': 10, 'state_name': 'Goa'}, {'state_id': 11, 'state_name': 'Gujarat'}, {'state_id': 12, 'state_name': 'Haryana'}, {'state_id': 13, 'state_name': 'Himachal Pradesh'}, {'state_id': 14, 'state_name': 'Jammu and Kashmir'}, {'state_id': 15, 'state_name': 'Jharkhand'}, {'state_id': 16, 'state_name': 'Karnataka'}, {'state_id': 17, 'state_name': 'Kerala'}, {'state_id': 18, 'state_name': 'Ladakh'}, {'state_id': 19, 'state_name': 'Lakshadweep'}, {'state_id': 20, 'state_name': 'Madhya Pradesh'}, {'st
# ...

# %%
cowin.get_districts(9)
# Out:
# {'districts': [{'district_id': 141, 'district_name': 'Central Delhi'},
#   {'district_id': 145, 'district_name': 'East Delhi'},
#   {'district_id': 140, 'district_name': 'New Delhi'},
#   {'district_id': 146, 'district_name': 'North Delhi'},
#   {'district_id': 147, 'district_name': 'North East Delhi'},
#   {'district_id': 143, 'district_name': 'North West Delhi'},
#   {'district_id': 148, 'district_name': 'Shahdara'},
#   {'district_id': 149, 'district_name': 'South Delhi'},
#   {'district_id': 144, 'district_name': 'South East Delhi'},
#   {'district_id': 150, 'district_name': 'South West Delhi'},
#   {'district_id': 142, 'district_name': 'West Delhi'}],
#  'ttl': 24}

# %%
state_id = '9'
districts = cowin.get_districts(state_id)
print(districts)
# Out:
# {'districts': [{'district_id': 141, 'district_name': 'Central Delhi'}, {'district_id': 145, 'district_name': 'East Delhi'}, {'district_id': 140, 'district_name': 'New Delhi'}, {'district_id': 146, 'district_name': 'North Delhi'}, {'district_id': 147, 'district_name': 'North East Delhi'}, {'district_id': 143, 'district_name': 'North West Delhi'}, {'district_id': 148, 'district_name': 'Shahdara'}, {'district_id': 149, 'district_name': 'South Delhi'}, {'district_id': 144, 'district_name': 'South East Delhi'}, {'district_id': 150, 'district_name': 'South West Delhi'}, {'district_id': 142, 'district_name': 'West Delhi'}], 'ttl': 24}

# %% [markdown]
# #### Getting all available centers in 'North West Delhi'

# %%
district_id = '143'

# here date is today's date by default and no min_age_limit specified
available_centers = cowin.get_availability_by_district(district_id)
print(available_centers)
# Out:
# {'centers': [{'center_id': 593353, 'name': 'Lalita Hospital', 'address': 'A-208,209 Rajeev Nagar Begumpur Delhi-110086', 'state_name': 'Delhi', 'district_name': 'North West Delhi', 'block_name': 'Not Applicable', 'pincode': 110086, 'lat': 28, 'long': 77, 'from': '09:00:00', 'to': '18:00:00', 'fee_type': 'Paid', 'sessions': [{'session_id': '5d4eea28-ab5f-4b3c-887b-73aaa8a67470', 'date': '09-05-2021', 'available_capacity': 0, 'min_age_limit': 45, 'vaccine': 'COVAXIN', 'slots': ['09:00AM-11:00AM', '11:00AM-01:00PM', '01:00PM-03:00PM', '03:00PM-06:00PM']}, {'session_id': '4dadc774-b789-4ba6-9f7c-6766478f5c93', 'date': '10-05-2021', 'available_capacity': 0, 'min_age_limit': 45, 'vaccine': 'COVAXIN', 'slots': ['09:00AM-11:00AM', '11:00AM-01:00PM', '01:00PM-03:00PM', '03:00PM-06:00PM']}, {'session_id': '91f40679-2654-4b77-bc31-a7f541cbdcdf', 'date': '11-05-2021', 'available_capacity': 0, 'min_age_limit': 45, 'vaccine': 'COVAXIN', 'slots': ['09:00AM-11:00AM', '11:00AM-01:00PM', '01:00PM-03:0
# ...

# %% [markdown]
# #### Getting all available centers in 'North West Delhi' for Age 18+

# %%
district_id = '143'

# here date is today's date by default
available_centers = cowin.get_availability_by_district(district_id, min_age_limt=18)
print(available_centers)
# Out:
# {'centers': [{'center_id': 694024, 'name': 'GGSSS B Block Anandvas Site 4', 'address': 'Block B Shakurpur Colony Shakurpur Delhi 110034', 'state_name': 'Delhi', 'district_name': 'North West Delhi', 'block_name': 'Not Applicable', 'pincode': 110034, 'lat': 28, 'long': 77, 'from': '09:00:00', 'to': '17:00:00', 'fee_type': 'Free', 'sessions': [{'session_id': '788f939a-5457-495d-b33e-dac7cda9a711', 'date': '10-05-2021', 'available_capacity': 0, 'min_age_limit': 18, 'vaccine': 'COVAXIN', 'slots': ['09:00AM-11:00AM', '11:00AM-01:00PM', '01:00PM-03:00PM', '03:00PM-05:00PM']}]}, {'center_id': 695050, 'name': 'GCSV Pkt8 Ph-3 Sec21 Rohini S1', 'address': 'GCSV Pocket 9 Sector 21 Rohini New Delhi Delhi 110086', 'state_name': 'Delhi', 'district_name': 'North West Delhi', 'block_name': 'Not Applicable', 'pincode': 110086, 'lat': 28, 'long': 77, 'from': '09:00:00', 'to': '17:00:00', 'fee_type': 'Free', 'sessions': [{'session_id': '16379a39-fc48-49c2-af2c-ec1eda26c4ae', 'date': '10-05-2021', 'avail
# ...

# %%
available_centers = cowin.get_availability_by_district(district_id='143', min_age_limt=18)
l = available_centers.get("centers")
l[0].get("sessions")[0].get("available_capacity")
# Out:
# 0

# %% [markdown]
# #### Getting all available centers by pincode 110085

# %%
# here date is today's date by default and no min_age_limit specified
available_centers = cowin.get_availability_by_pincode(pin_code='110085')
print(available_centers)
# Out:
# {'centers': [{'center_id': 642824, 'name': 'Dr BSA Hospital DH 6', 'address': 'Sector -VI, Rohini, Delhi - 85', 'state_name': 'Delhi', 'district_name': 'North West Delhi', 'block_name': 'Not Applicable', 'pincode': 110085, 'lat': 28, 'long': 77, 'from': '09:00:00', 'to': '21:00:00', 'fee_type': 'Free', 'sessions': [{'session_id': '38934fba-041e-4a4e-846e-af8be8dccfb5', 'date': '10-05-2021', 'available_capacity': 0, 'min_age_limit': 45, 'vaccine': 'COVISHIELD', 'slots': ['09:00AM-12:00PM', '12:00PM-03:00PM', '03:00PM-06:00PM', '06:00PM-09:00PM']}, {'session_id': 'b431e3e3-ff82-440c-ad31-28e59ab3b4a3', 'date': '11-05-2021', 'available_capacity': 82, 'min_age_limit': 45, 'vaccine': 'COVISHIELD', 'slots': ['09:00AM-12:00PM', '12:00PM-03:00PM', '03:00PM-06:00PM', '06:00PM-09:00PM']}, {'session_id': '57046416-45dd-44d1-a256-50697d40c724', 'date': '12-05-2021', 'available_capacity': 181, 'min_age_limit': 45, 'vaccine': 'COVISHIELD', 'slots': ['09:00AM-12:00PM', '12:00PM-03:00PM', '03:00PM-0
# ...
